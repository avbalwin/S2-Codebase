# %% [markdown]
# <a href="https://colab.research.google.com/github/avbalwin/S2-Codebase/blob/main/Experiment_No_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment No.3
#
# Evaluating gradient of a scalar field and visualize

# %% [markdown]
# **Case** Find the gradient of the scalar field $f=x^2+y^2+z^2$ and plot the gradient field.

# %% [markdown]
# **Solution**

# %% [markdown]
# ##Evaluating the gradient of the Scalar Field

# %%
import sympy as sp

#Define the symbols
x,y,z = sp.symbols('x y z')

#Define the scalar field
scalar_field = x**2 + y**2 + z**2 # Example scalar field
scalar_field
# Out:
# x**2 + y**2 + z**2

# %%
#Compute the gradient
gradient = sp.Matrix([sp.diff(scalar_field, var) for var in [x,y,z]])
print("The gradient of the scalar field is")
gradient
#
# Out:
# The gradient of the scalar field is
# Matrix([
# [2*x],
# [2*y],
# [2*z]])

# %% [markdown]
# ##Plotting the Gradient of the scalar field

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a grid of points where you want to evaluate the gradient
x_vals = np.linspace(-10, 10, 20)
y_vals = np.linspace(-10, 10, 20)
z_val = 0 # For 2D visualization in the z=0 plane

X,Y = np.meshgrid(x_vals, y_vals)

# Intialize arrays to store gradient components
U = np.zeros_like(X, dtype=float)
V = np.zeros_like(X, dtype=float)

# Evaluate the gradient at each point
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    grad_evaluated = gradient.subs({x: X[i,j], y: Y[i,j], z: z_val})
    U[i,j] = grad_evaluated[0]
    V[i,j] = grad_evaluated[1]

# Plot the gradient vectors using matplotlib
fig, ax = plt.subplots()
ax.quiver(X,Y,U,V)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient of the Scalar Field')

plt.show()

# %%
import sympy as sp

#Define the symbols
x,y, = sp.symbols('x y ')

#Define the scalar field
scalar_field1 = 100*sp.exp(-(x**2 + y**2)/2) # Example scalar field
scalar_field1
# Out:
# 100*exp(-x**2/2 - y**2/2)

# %%
#Compute the gradient
gradient1 = sp.Matrix([sp.diff(scalar_field1, var) for var in [x,y]])
print("The gradient of the scalar field is")
gradient1
#
# Out:
# The gradient of the scalar field is
# Matrix([
# [-100*x*exp(-x**2/2 - y**2/2)],
# [-100*y*exp(-x**2/2 - y**2/2)]])

# %%
import numpy as np
import matplotlib.pyplot as plt
# Define the region of the plate
x_vals = np.linspace(-5, 5, 100)
y_vals = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x_vals, y_vals)

# Define the temperature distribution function
T=100*np.exp(-((X**2 + Y**2)/2))

# Create a contour plot of the temperature distribution
plt.contourf(X, Y, T, levels=10, cmap='inferno')
plt.colorbar(label='Temperature (°C)')
plt.title('Temperature Distribution T(x, y)')
plt.xlabel('x (meters)')
plt.ylabel('y (meters)')
plt.show()

# %%
# Define the region of the plate
x_vals = np.linspace(-5, 5, 20)
y_vals = np.linspace(-5, 5, 20)
X, Y = np.meshgrid(x_vals, y_vals)

# Intialize arrays to store gradient components
U = np.zeros_like(X, dtype=float)
V = np.zeros_like(X, dtype=float)

# Evaluate the gradient at each point
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    grad_evaluated = gradient1.subs({x: X[i,j], y: Y[i,j]})
    U[i,j] = float(grad_evaluated[0])
    V[i,j] = float(grad_evaluated[1])

# Plot the gradient vectors using matplotlib
fig, ax = plt.subplots()
ax.quiver(X,Y,U,V)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient of the Scalar Field')

plt.show()

# %% [markdown]
# ## Application Problem: Signal Power Distribution in a 2D Region
#
# In wireless communication and electromagnetic theory, the signal power density around a transmitting antenna varies with position.
# The gradient of power density indicates the direction in which the signal strength increases most rapidly.
#
# Consider the scalar field representing signal power distribution:
#
# $P(x, y, z)=x^2+y^2$
#
#
# * Compute the gradient of the power distribution.
#
# * Visualize the gradient vectors in the z = 0 plane.

# %%
import sympy as sp

#Define the symbols
x,y, = sp.symbols('x y ')

#Define the scalar field
scalar_field2 = x**2 + y**2  # Example scalar field
scalar_field2
# Out:
# x**2 + y**2

# %%
#Compute the gradient
gradient2 = sp.Matrix([sp.diff(scalar_field2, var) for var in [x,y,z]])
print("The gradient of the scalar field is")
gradient2
#
# Out:
# The gradient of the scalar field is
# Matrix([
# [2*x],
# [2*y],
# [  0]])

# %%
# Define the region of the plate
x_vals = np.linspace(-5, 5, 20)
y_vals = np.linspace(-5, 5, 20)
z_val = 0 # For 2D visualization in the z=0 plane
X, Y = np.meshgrid(x_vals, y_vals)

# Intialize arrays to store gradient components
U = np.zeros_like(X, dtype=float)
V = np.zeros_like(X, dtype=float)

# Evaluate the gradient at each point
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    grad_evaluated = gradient2.subs({x: X[i,j], y: Y[i,j]})
    U[i,j] = float(grad_evaluated[0])
    V[i,j] = float(grad_evaluated[1])

# Plot the gradient vectors using matplotlib
fig, ax = plt.subplots()
ax.quiver(X,Y,U,V)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient of the Scalar Field')

plt.show()
